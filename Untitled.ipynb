# %%
import json
import pandas as pd

df_1= pd.read_csv("results/2021-03-16_19-34-32/user_trips.csv")
print(df_1.dtypes)
df_2= pd.read_csv("results/2021-03-16_19-36-39/user_trips.csv")
df_3= pd.read_csv("results/2021-03-16_19-38-57/user_trips.csv")
df_4= pd.read_csv("results/2021-03-16_19-40-20/user_trips.csv")
df_5= pd.read_csv("results/2021-03-16_19-41-40/user_trips.csv")
df_5_2=pd.read_csv("results/2021-03-16_19-42-52/user_trips.csv")
df_5_3=pd.read_csv("results/2021-03-16_19-45-27/user_trips.csv")
df_5_4=pd.read_csv("results/2021-03-16_19-47-48/user_trips.csv")
df_5_5=pd.read_csv("results/2021-03-16_19-52-17/user_trips.csv")
# Look at the column names
#print(df.columns)
df_1.head()
# Out:
# user_id                           int64
# bike_id                          object
# mode                              int64
# time_departure                    int64
# time_target                       int64
# time_walk_origin                 object
# time_ride                        object
# time_wait                       float64
# time_walk_destination            object
# origin_lon                      float64
# origin_lat                      float64
# destination_lon                 float64
# destination_lat                 float64
# origin_visited_stations          object
# destination_visited_stations     object
# origin_station                   object
# destination_station              object
# magic_bike                        int64
# magic_dock                        int64
# bike_lon                        float64
# bike_lat                        float64
# dtype: object
#    user_id bike_id  mode  time_departure  time_target time_walk_origin  \
# ...

# %%
df_1 = df_1[df_1['time_walk_origin']!= 'None']
df_1[['time_walk_origin', 'time_walk_destination', 'time_ride']] = df_1[['time_walk_origin', 'time_walk_destination','time_ride']].apply(pd.to_numeric) 
print('DF1:')
print(df_1['time_walk_origin'].describe())
print(df_1['time_ride'].describe())
print(df_1['time_walk_destination'].describe())


df_2 = df_2[df_2['time_walk_origin']!= 'None']
df_2[['time_walk_origin', 'time_walk_destination', 'time_ride']] = df_2[['time_walk_origin', 'time_walk_destination','time_ride']].apply(pd.to_numeric) 
print('DF2:')
print(df_2['time_walk_origin'].describe())
print(df_2['time_ride'].describe())
print(df_2['time_walk_destination'].describe())



df_3 = df_3[df_3['time_walk_origin']!= 'None']
df_3[['time_walk_origin', 'time_walk_destination', 'time_ride']] = df_3[['time_walk_origin', 'time_walk_destination','time_ride']].apply(pd.to_numeric) 
print('DF3:')
print(df_3['time_walk_origin'].describe())
print(df_3['time_ride'].describe())
print(df_3['time_walk_destination'].describe())



df_4 = df_4[df_4['time_walk_origin']!= 'None']
df_4[['time_walk_origin', 'time_walk_destination', 'time_ride']] = df_4[['time_walk_origin', 'time_walk_destination','time_ride']].apply(pd.to_numeric) 
print('DF4:')
print(df_4['time_walk_origin'].describe())
print(df_4['time_ride'].describe())
print(df_4['time_walk_destination'].describe())


df_5 = df_5[df_5['time_walk_origin']!= 'None']
df_5[['time_walk_origin', 'time_walk_destination', 'time_ride']] = df_5[['time_walk_origin', 'time_walk_destination','time_ride']].apply(pd.to_numeric) 
print('DF5:')
print(df_5['time_walk_origin'].describe())
print(df_5['time_ride'].describe())
print(df_5['time_walk_destination'].describe())


df_5_2 = df_5_2[df_5_2['time_walk_origin']!= 'None']
df_5_2[['time_walk_origin', 'time_walk_destination', 'time_ride']] = df_5_2[['time_walk_origin', 'time_walk_destination','time_ride']].apply(pd.to_numeric) 
print('DF5_2:')
print(df_5_2['time_walk_origin'].describe())
print(df_5_2['time_ride'].describe())
print(df_5_2['time_walk_destination'].describe())


df_5_3 = df_5_3[df_5_3['time_walk_origin']!= 'None']
df_5_3[['time_walk_origin', 'time_walk_destination', 'time_ride']] = df_5_3[['time_walk_origin', 'time_walk_destination','time_ride']].apply(pd.to_numeric) 
print('DF5_3:')
print(df_5_3['time_walk_origin'].describe())
print(df_5_3['time_ride'].describe())
print(df_5_3['time_walk_destination'].describe())

df_5_4 = df_5_4[df_5_4['time_walk_origin']!= 'None']
df_5_4[['time_walk_origin', 'time_walk_destination', 'time_ride']] = df_5_4[['time_walk_origin', 'time_walk_destination','time_ride']].apply(pd.to_numeric) 
print('DF5_4:')
print(df_5_4['time_walk_origin'].describe())
print(df_5_4['time_ride'].describe())
print(df_5_4['time_walk_destination'].describe())

df_5_5 = df_5_5[df_5_5['time_walk_origin']!= 'None']
df_5_5[['time_walk_origin', 'time_walk_destination', 'time_ride']] = df_5_5[['time_walk_origin', 'time_walk_destination','time_ride']].apply(pd.to_numeric) 
print('DF5_5:')
print(df_5_5['time_walk_origin'].describe())
print(df_5_5['time_ride'].describe())
print(df_5_5['time_walk_destination'].describe())


#print(df_1.dtypes)
#df_1.shape

#df['user_id'].min()
#df['user_id'].max()
#df['user_id'].mean()
#df['user_id'].std()
#df['user_id'].count()

#print(df['mode'].value_counts())
#print(df['bike_id'].value_counts(normalize='True'))
#df_bikes= df.groupby('bike_id')
#df_bikes.head(5)
# Out:
# DF1:
# count    6974.000000
# mean      173.145971
# std       136.192944
# min         1.000000
# 25%        96.000000
# 50%       157.000000
# 75%       223.000000
# max      1767.000000
# Name: time_walk_origin, dtype: float64
# count    6974.000000
# mean      830.622025
# std       544.431080
# min         1.000000
# 25%       436.000000
# 50%       713.000000
# 75%      1102.000000
# max      4133.000000
# Name: time_ride, dtype: float64
# count    6974.000000
# mean      182.809292
# std       156.876396
# min         0.000000
# 25%       103.000000
# 50%       161.000000
# 75%       226.000000
# max      1766.000000
# Name: time_walk_destination, dtype: float64
# DF2:
# count    6974.000000
# mean      173.764984
# std       133.013261
# min         1.000000
# 25%        96.000000
# 50%       157.000000
# 75%       223.000000
# max      1767.000000
# Name: time_walk_origin, dtype: float64
# count    6974.000000
# mean      824.837253
# std       541.529470
# ...

# %%
no_trip = df[df['time_walk_origin']== 'None']
no_trip.shape
# Out:
# (3572, 21)
